# %% [markdown]
# <a href="https://colab.research.google.com/github/AlicjaTomaszewska/Neutral_Network_Stock/blob/main/Projekt_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Apr  7 16:01:45 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !gdown 1M_YjQxTNTYPgJa4ABjTHiYa7fOd2wVL3
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M_YjQxTNTYPgJa4ABjTHiYa7fOd2wVL3
# To: /content/Alice_AI.zip
# 100% 55.0k/55.0k [00:00<00:00, 61.9MB/s]

# %%
# !unzip Alice_AI.zip
# Out:
# Archive:  Alice_AI.zip
#   inflating: Alice_AI/123.ipynb
#   inflating: Alice_AI/mwig40.csv
#   inflating: Alice_AI/wig20.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import tensorflow.compat.v2 as tf
import plotly.graph_objects as go
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import optimizers
from keras.callbacks import ModelCheckpoint, EarlyStopping
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pickle
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df_WIG20 = pd.read_csv('/content/Alice_AI/wig20.csv', header=0) #loading data
df_mWIG40 = pd.read_csv('/content/Alice_AI/mwig40.csv', header=0)

# %%
df_WIG20['Data'] = pd.to_datetime(df_WIG20['Data'], format='%Y-%m-%d') #changing to data format
df_mWIG40['Data'] = pd.to_datetime(df_mWIG40['Data'], format='%Y-%m-%d')

# %%
df = pd.merge(left=df_WIG20, right=df_mWIG40, how='left', left_on='Data', right_on='Data') #merging two tables

# %%
df['Rok'] = df['Data'].dt.year  #Creating 3 new columns: Year, Month and Day and dropping Date column
df['Miesiąc'] = df['Data'].dt.month
df['Dzień'] = df['Data'].dt.day
df.drop(['Data'], axis=1, inplace=True)
df.drop(['Najwyzszy_x', 'Najwyzszy_y', 'Najnizszy_x', 'Najnizszy_y', 'Wolumen_x', 'Wolumen_y'], axis=1, inplace=True) #dropping unnecessary columns

# %%
df['Otwarcie_x'] = pd.to_numeric(df['Otwarcie_x'], errors='coerce') #changing format to numeric
df['Otwarcie_y'] = pd.to_numeric(df['Otwarcie_y'], errors='coerce')
df['Zamkniecie_x'] = pd.to_numeric(df['Zamkniecie_x'], errors='coerce')
df['Zamkniecie_y'] = pd.to_numeric(df['Zamkniecie_y'], errors='coerce')

# %%
df.dropna(axis=0, inplace=True)

# %%
df_t_minus_5 = df.iloc[0:-5, :].reset_index(drop=True)
df_t_minus_4 = df.iloc[1:-4, :-3].reset_index(drop=True)
df_t_minus_3 = df.iloc[2:-3, :-3].reset_index(drop=True)
df_t_minus_2 = df.iloc[3:-2, :-3].reset_index(drop=True)
df_t_minus_1 = df.iloc[4:-1, :-3].reset_index(drop=True)

# %%
df_features = pd.concat([df_t_minus_5, df_t_minus_4, df_t_minus_3, df_t_minus_2, df_t_minus_1], axis=1) #creating features table

df_target = df.iloc[5:, 0].reset_index(drop=True)

X = df_features.values
Y = df_target.values

# %%
print(df.head(10))
print(df_target.head(10))
print(df_features.head(10))
# Out:
#    Otwarcie_x  Zamkniecie_x  Otwarcie_y  Zamkniecie_y   Rok  Miesiąc  Dzień
# 0     2250.26       2272.09     4706.96       4698.32  2018        3     20
# 1     2268.87       2320.77     4706.00       4735.44  2018        3     21
# 2     2313.07       2274.10     4728.41       4652.00  2018        3     22
# 3     2254.88       2257.22     4626.77       4611.80  2018        3     23
# 4     2260.83       2240.65     4604.79       4557.61  2018        3     26
# 5     2258.98       2246.32     4594.24       4566.10  2018        3     27
# 6     2238.85       2203.70     4557.36       4531.28  2018        3     28
# 7     2215.94       2210.38     4539.87       4554.89  2018        3     29
# 8     2211.17       2239.15     4546.27       4559.40  2018        4      3
# 9     2238.25       2200.99     4574.04       4599.98  2018        4      4
# 0    2258.98
# 1    2238.85
# 2    2215.94
# 3    2211.17
# 4    2238.25
# 5    2222.86
# 6    2244.33
# 7    2261.72
# 8    2280.21
# 9    2274.22
# Name: Otwarcie_x, dtype: float64
#    Otwarcie_x  Zamkniecie_x  Otwarcie_y  Zamkniecie_y   Rok  Miesiąc  Dzień  \
# 0     2250.26       2272.09     4706.96       4698.32  2018        3     20
# 1     2268.87       2320.77     4706.00       4735.44  2018        3     21
# 2     2313.07       2274.10     4728.41       4652.00  2018        3     22
# 3     2254.88       2257.22     4626.77       4611.80  2018        3     23
# 4     2260.83       2240.65     4604.79       4557.61  2018        3     26
# 5     2258.98       2246.32     4594.24       4566.10  2018        3     27
# 6     2238.85       2203.70     4557.36       4531.28  2018        3     28
# 7     2215.94       2210.38     4539.87       4554.89  2018        3     29
# 8     2211.17       2239.15     4546.27       4559.40  2018        4      3
# 9     2238.25       2200.99     4574.04       4599.98  2018        4      4
#
#    Otwarcie_x  Zamkniecie_x  Otwarcie_y  ...  Otwarcie_y  Zamkniecie_y  \
# 0     2268.87       2320.77     4706.00  ...     4728.41       4652.00
# 1     2313.07       2274.10     4728.41  ...     4626.77       4611.80
# 2     2254.88       2257.22     4626.77  ...     4604.79       4557.61
# 3     2260.83       2240.65     4604.79  ...     4594.24       4566.10
# 4     2258.98       2246.32     4594.24  ...     4557.36       4531.28
# 5     2238.85       2203.70     4557.36  ...     4539.87       4554.89
# 6     2215.94       2210.38     4539.87  ...     4546.27       4559.40
# 7     2211.17       2239.15     4546.27  ...     4574.04       4599.98
# 8     2238.25       2200.99     4574.04  ...     4600.55       4636.68
# 9     2222.86       2243.58     4600.55  ...     4635.04       4655.67
#
#    Otwarcie_x  Zamkniecie_x  Otwarcie_y  Zamkniecie_y  Otwarcie_x  \
# 0     2254.88       2257.22     4626.77       4611.80     2260.83
# 1     2260.83       2240.65     4604.79       4557.61     2258.98
# 2     2258.98       2246.32     4594.24       4566.10     2238.85
# 3     2238.85       2203.70     4557.36       4531.28     2215.94
# 4     2215.94       2210.38     4539.87       4554.89     2211.17
# 5     2211.17       2239.15     4546.27       4559.40     2238.25
# 6     2238.25       2200.99     4574.04       4599.98     2222.86
# 7     2222.86       2243.58     4600.55       4636.68     2244.33
# 8     2244.33       2258.80     4635.04       4655.67     2261.72
# 9     2261.72       2262.16     4650.70       4670.85     2280.21
#
#    Zamkniecie_x  Otwarcie_y  Zamkniecie_y
# 0       2240.65     4604.79       4557.61
# 1       2246.32     4594.24       4566.10
# 2       2203.70     4557.36       4531.28
# 3       2210.38     4539.87       4554.89
# 4       2239.15     4546.27       4559.40
# 5       2200.99     4574.04       4599.98
# 6       2243.58     4600.55       4636.68
# 7       2258.80     4635.04       4655.67
# 8       2262.16     4650.70       4670.85
# 9       2274.81     4667.55       4641.66
#
# [10 rows x 23 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state=123) #we take 10% of data to test

# %%
#Normalization
mean = X_train.mean(axis=0)
std = X_train.std(axis=0)
X_train = (X_train - mean)/ std
X_test = (X_test - mean)/ std

# %%
#Network architecture
n_features = X_train.shape[1]
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(n_features,))) #layer with 64 neurons
model.add(Dense(64, activation='relu'))
model.add(Dense(1))  #output layer with one neuron
optimizers.RMSprop(lr = 0.001) #learning algorithm, learning rate=0.001
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/rmsprop.py:143: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
#Network training
model.compile(optimizer='RMSprop', loss='mse', metrics=['mae'])
filepath = 'models/{epoch:02d}-{loss:.0f}-{val_loss:.0f}-{mae:.0f}-{val_mae:.0f}.hdf5'

callbacks = [EarlyStopping(monitor='val_loss', patience=50), #helps to avoid overfitting or overtraining
            ModelCheckpoint(filepath, monitor='loss', save_best_only=True, mode='min')]
history = model.fit(X_train, Y_train, validation_split=0.1, epochs=1000, callbacks=callbacks, batch_size=1)
# Out:
# Epoch 1/1000
# 839/839 [==============================] - 7s 3ms/step - loss: 2374374.7500 - mae: 1397.6816 - val_loss: 624753.5625 - val_mae: 647.0146
# Epoch 2/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 544423.8750 - mae: 593.8993 - val_loss: 345388.0312 - val_mae: 474.9177
# Epoch 3/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 303246.2500 - mae: 435.4490 - val_loss: 188998.3906 - val_mae: 361.9772
# Epoch 4/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 192990.7656 - mae: 357.9901 - val_loss: 139962.0000 - val_mae: 292.4367
# Epoch 5/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 143166.4062 - mae: 304.8586 - val_loss: 115307.9453 - val_mae: 260.7755
# Epoch 6/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 106171.7188 - mae: 257.3476 - val_loss: 76548.3281 - val_mae: 206.6765
# Epoch 7/1000
# 839/839 [==============================] - 3s 4ms/step - loss: 73290.7266 - mae: 210.7353 - val_loss: 52955.5430 - val_mae: 171.0455
# Epoch 8/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 45073.1328 - mae: 163.6265 - val_loss: 31593.5586 - val_mae: 135.5654
# Epoch 9/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 25951.7734 - mae: 122.2459 - val_loss: 16917.2148 - val_mae: 97.2545
# Epoch 10/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 14119.1934 - mae: 92.5258 - val_loss: 10027.1631 - val_mae: 78.6594
# Epoch 11/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 8046.3813 - mae: 68.9401 - val_loss: 11018.0029 - val_mae: 79.0857
# Epoch 12/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 4296.8398 - mae: 51.2824 - val_loss: 3555.8743 - val_mae: 46.5261
# Epoch 13/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 2587.9744 - mae: 39.3005 - val_loss: 1344.6056 - val_mae: 28.1776
# Epoch 14/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 1557.2626 - mae: 29.8945 - val_loss: 857.4175 - val_mae: 23.9024
# Epoch 15/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 1055.6384 - mae: 24.9820 - val_loss: 519.2191 - val_mae: 17.5645
# Epoch 16/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 838.7686 - mae: 22.0985 - val_loss: 935.8992 - val_mae: 24.9916
# Epoch 17/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 689.4166 - mae: 20.2112 - val_loss: 500.0636 - val_mae: 16.9017
# Epoch 18/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 639.7813 - mae: 18.7481 - val_loss: 760.4841 - val_mae: 23.7795
# Epoch 19/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 619.8568 - mae: 18.3230 - val_loss: 811.0328 - val_mae: 20.8173
# Epoch 20/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 558.6950 - mae: 17.4959 - val_loss: 1044.9792 - val_mae: 24.7833
# Epoch 21/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 557.8128 - mae: 17.8071 - val_loss: 563.2676 - val_mae: 19.6637
# Epoch 22/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 507.7469 - mae: 16.2145 - val_loss: 302.2061 - val_mae: 13.5398
# Epoch 23/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 521.2853 - mae: 16.6257 - val_loss: 753.2786 - val_mae: 21.3318
# Epoch 24/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 502.7968 - mae: 16.1354 - val_loss: 906.9267 - val_mae: 23.8747
# Epoch 25/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 506.0206 - mae: 16.5820 - val_loss: 145.4603 - val_mae: 8.7517
# Epoch 26/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 517.3608 - mae: 16.4064 - val_loss: 473.6263 - val_mae: 17.7977
# Epoch 27/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 479.6588 - mae: 15.7637 - val_loss: 123.3871 - val_mae: 8.8599
# Epoch 28/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 470.7453 - mae: 16.0583 - val_loss: 600.0917 - val_mae: 18.9805
# Epoch 29/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 486.8377 - mae: 16.3625 - val_loss: 138.4544 - val_mae: 8.7292
# Epoch 30/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 498.0595 - mae: 16.3239 - val_loss: 366.6390 - val_mae: 14.3396
# Epoch 31/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 486.3772 - mae: 16.2840 - val_loss: 223.9120 - val_mae: 12.2096
# Epoch 32/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 502.9876 - mae: 15.8706 - val_loss: 174.5040 - val_mae: 9.9800
# Epoch 33/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 463.5986 - mae: 15.8648 - val_loss: 64.3991 - val_mae: 6.1245
# Epoch 34/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 475.8095 - mae: 16.1157 - val_loss: 233.7151 - val_mae: 12.1395
# Epoch 35/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 445.7762 - mae: 15.3723 - val_loss: 226.6426 - val_mae: 12.2662
# Epoch 36/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 460.1467 - mae: 15.5693 - val_loss: 744.9231 - val_mae: 20.4832
# Epoch 37/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 468.5109 - mae: 15.2974 - val_loss: 313.5941 - val_mae: 13.7832
# Epoch 38/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 467.1523 - mae: 15.6886 - val_loss: 309.6068 - val_mae: 14.0688
# Epoch 39/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 480.2414 - mae: 15.5817 - val_loss: 150.1610 - val_mae: 9.0410
# Epoch 40/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 496.7824 - mae: 15.9435 - val_loss: 119.3254 - val_mae: 8.1311
# Epoch 41/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 473.2052 - mae: 15.7525 - val_loss: 197.0931 - val_mae: 11.6924
# Epoch 42/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 471.2167 - mae: 16.0133 - val_loss: 1450.4410 - val_mae: 28.5772
# Epoch 43/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 459.1256 - mae: 15.8420 - val_loss: 190.5902 - val_mae: 10.6092
# Epoch 44/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 459.5521 - mae: 15.3074 - val_loss: 2110.2090 - val_mae: 36.2333
# Epoch 45/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 465.4922 - mae: 15.6946 - val_loss: 75.9409 - val_mae: 6.6694
# Epoch 46/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 479.5730 - mae: 16.1372 - val_loss: 582.2066 - val_mae: 20.0429
# Epoch 47/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 456.3607 - mae: 15.8216 - val_loss: 229.4727 - val_mae: 12.2062
# Epoch 48/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 434.9855 - mae: 15.4342 - val_loss: 289.5433 - val_mae: 13.6206
# Epoch 49/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 471.6446 - mae: 15.7321 - val_loss: 269.9857 - val_mae: 13.2114
# Epoch 50/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 470.5957 - mae: 15.9059 - val_loss: 620.8893 - val_mae: 21.2212
# Epoch 51/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 471.8533 - mae: 15.6837 - val_loss: 142.2997 - val_mae: 8.7115
# Epoch 52/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 432.5701 - mae: 15.2008 - val_loss: 463.7546 - val_mae: 15.8661
# Epoch 53/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 435.1683 - mae: 15.3416 - val_loss: 218.8658 - val_mae: 12.3609
# Epoch 54/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 436.3699 - mae: 15.3636 - val_loss: 570.0134 - val_mae: 17.7429
# Epoch 55/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 455.6886 - mae: 15.5675 - val_loss: 377.1574 - val_mae: 15.9835
# Epoch 56/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 447.6382 - mae: 15.3513 - val_loss: 103.4983 - val_mae: 7.9009
# Epoch 57/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 417.4703 - mae: 15.4303 - val_loss: 403.2578 - val_mae: 16.4726
# Epoch 58/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 444.9067 - mae: 15.4475 - val_loss: 126.0870 - val_mae: 8.5508
# Epoch 59/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 456.2957 - mae: 15.7875 - val_loss: 1119.3665 - val_mae: 28.0000
# Epoch 60/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 461.3738 - mae: 15.7332 - val_loss: 147.0042 - val_mae: 9.1379
# Epoch 61/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 479.4544 - mae: 15.6911 - val_loss: 661.6679 - val_mae: 19.8206
# Epoch 62/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 461.3126 - mae: 15.4883 - val_loss: 482.2871 - val_mae: 17.8673
# Epoch 63/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 430.6686 - mae: 15.0412 - val_loss: 245.6071 - val_mae: 11.7292
# Epoch 64/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 464.7612 - mae: 15.5451 - val_loss: 705.1908 - val_mae: 20.6274
# Epoch 65/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 436.8373 - mae: 15.3235 - val_loss: 452.1396 - val_mae: 18.0292
# Epoch 66/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 466.2376 - mae: 15.3471 - val_loss: 689.2843 - val_mae: 20.7656
# Epoch 67/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 441.0562 - mae: 15.0317 - val_loss: 275.4811 - val_mae: 12.2865
# Epoch 68/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 432.6319 - mae: 15.0938 - val_loss: 132.2875 - val_mae: 9.0358
# Epoch 69/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 446.1005 - mae: 15.1825 - val_loss: 537.1085 - val_mae: 17.4307
# Epoch 70/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 427.6927 - mae: 15.1093 - val_loss: 326.9037 - val_mae: 14.3410
# Epoch 71/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 444.3558 - mae: 15.0381 - val_loss: 503.4453 - val_mae: 17.5558
# Epoch 72/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 450.0227 - mae: 15.0679 - val_loss: 409.0516 - val_mae: 17.1032
# Epoch 73/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 435.1669 - mae: 15.5827 - val_loss: 229.7982 - val_mae: 11.4420
# Epoch 74/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 429.5346 - mae: 14.9230 - val_loss: 1150.6025 - val_mae: 25.4379
# Epoch 75/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 436.9412 - mae: 14.9441 - val_loss: 295.0614 - val_mae: 14.5755
# Epoch 76/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 442.6317 - mae: 15.1752 - val_loss: 684.2319 - val_mae: 21.8677
# Epoch 77/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 441.0023 - mae: 15.0321 - val_loss: 467.3327 - val_mae: 16.8718
# Epoch 78/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 432.5925 - mae: 14.8132 - val_loss: 226.3871 - val_mae: 12.8924
# Epoch 79/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 422.2427 - mae: 15.0533 - val_loss: 554.7156 - val_mae: 17.7338
# Epoch 80/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 450.0602 - mae: 15.2441 - val_loss: 552.9218 - val_mae: 18.2938
# Epoch 81/1000
# 839/839 [==============================] - 2s 3ms/step - loss: 428.5645 - mae: 14.9840 - val_loss: 472.8272 - val_mae: 17.5422
# Epoch 82/1000
# 839/839 [==============================] - 3s 3ms/step - loss: 427.6674 - mae: 15.0869 - val_loss: 429.7118 - val_mae: 17.3676
# Epoch 83/1000
# 839/839 [==============================] - 2s 2ms/step - loss: 414.7715 - mae: 14.9822 - val_loss: 96.0695 - val_mae: 7.6293

# %%
#Testing set evaluation
MSE, MAE = model.evaluate(X_test, Y_test)
print(MSE, MAE)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 149.8125 - mae: 8.7581
# 149.8124542236328 8.758132934570312

# %%
# save model
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
# load model
import os
import pickle

# Change the current working directory to 'Alice_AI'
os.chdir('/content/Alice_AI')

# Open the 'model.pkl' file and load the model
with open('model.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
# !zip models
# Out:
# zip error: Nothing to do! (models.zip)

# %%
pwd
# Out:
# '/content/Alice_AI'

# %%
# !zip -r /content/Alice_AI.zip /content/Alice_AI
# Out:
#   adding: content/Alice_AI/ (stored 0%)
#   adding: content/Alice_AI/mwig40.csv (deflated 60%)
#   adding: content/Alice_AI/.ipynb_checkpoints/ (stored 0%)
#   adding: content/Alice_AI/wig20.csv (deflated 62%)
#   adding: content/Alice_AI/models/ (stored 0%)
#   adding: content/Alice_AI/models/03-303246-188998-435-362.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/18-640-760-19-24.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/16-839-936-22-25.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/10-14119-10027-93-79.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/52-433-464-15-16.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/01-2374375-624754-1398-647.hdf5 (deflated 35%)
#   adding: content/Alice_AI/models/12-4297-3556-51-47.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/13-2588-1345-39-28.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/05-143166-115308-305-261.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/83-415-96-15-8.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/08-45073-31594-164-136.hdf5 (deflated 39%)
#   adding: content/Alice_AI/models/06-106172-76548-257-207.hdf5 (deflated 41%)
#   adding: content/Alice_AI/models/20-559-1045-17-25.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/02-544424-345388-594-475.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/33-464-64-16-6.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/35-446-227-15-12.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/48-435-290-15-14.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/19-620-811-18-21.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/04-192991-139962-358-292.hdf5 (deflated 41%)
#   adding: content/Alice_AI/models/57-417-403-15-16.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/14-1557-857-30-24.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/07-73291-52956-211-171.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/15-1056-519-25-18.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/17-689-500-20-17.hdf5 (deflated 41%)
#   adding: content/Alice_AI/models/24-503-907-16-24.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/09-25952-16917-122-97.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/27-480-123-16-9.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/28-471-600-16-19.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/11-8046-11018-69-79.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/22-508-302-16-14.hdf5 (deflated 40%)
#   adding: content/Alice_AI/models/21-558-563-18-20.hdf5 (deflated 41%)
#   adding: content/Alice_AI/123.ipynb (deflated 75%)
#   adding: content/Alice_AI/model.pkl (deflated 40%)

# %%
from google.colab import files
files.download('/content/Alice_AI.zip')

# %%
# Create a Linear Regression object
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, Y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# %%
# Predictions on test set
y_pred = model.predict(X_test)

# Plotting predicted and true values
fig = plt.figure(figsize=(30, 20), dpi=100) # Set figure size and dpi
plt.plot(Y_test, color='blue', label='True', linewidth=1)
plt.plot(y_pred, color='red', label='Predicted', linewidth=1)
plt.xlabel('Sample', fontsize = 30)
plt.ylabel('WIG20 value', fontsize = 30)
plt.title('WIG20 true vs predicted values', fontsize = 40)
plt.legend(prop={"size":40})
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.show()

# %%
# Predictions on test set
y_pred = model.predict(X_test)

# Calculating the difference between predicted and true values
diff = Y_test - y_pred

# Plotting the difference
fig = plt.figure(figsize=(30, 20), dpi=100) # Set figure size and dpi
plt.plot(diff, color='green', label='Difference', linewidth=1)
plt.xlabel('Sample', fontsize = 30)
plt.ylabel('Difference in WIG20 value', fontsize = 30)
plt.title('WIG20 true vs predicted difference', fontsize = 40)
plt.legend(prop={"size":40})
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.show()

# %%
# Predictions on test set
y_pred = model.predict(X_test)

# Calculating the difference between predicted and true values
diff = np.abs(Y_test - y_pred)

# Plotting the difference
fig = plt.figure(figsize=(30, 20), dpi=100) # Set figure size and dpi
plt.plot(diff, color='green', label='Absolute Difference', linewidth=1)
plt.xlabel('Sample', fontsize = 30)
plt.ylabel('Absolute Difference in WIG20 value', fontsize = 30)
plt.title('WIG20 true vs predicted absolute difference', fontsize = 40)
plt.legend(prop={"size":40})
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.show()
